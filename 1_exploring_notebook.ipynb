# %% [markdown]
# # Notebook for exploring the files that make up the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## File NoThemeTweets.csv

# %%
no_theme_tweets = pd.read_csv('dataset/NoThemeTweets.csv')

# %%
print(len(no_theme_tweets))
no_theme_tweets.sample(5)
# Out:
# 785814
#                          id  \
# 325610  1037956931573477377
# 295144  1037125476295364613
# 86822   1031646050153623553
# 222433  1033390239069478912
# 768186  1049202580956610560
#
#                                                tweet_text  \
# 325610  na moral eu só queria segurar a mãozinha do ki...
# 295144           Certíssimo!!! :D https://t.co/hf1tPF9Tnn
# 86822               @bibissbaby achei que eu era único :(
# 222433     bar :-( : 92ae8f6b-e835-4caa-af8e-2c567a00883a
# 768186  Há dois anos... um momento fantástico :) https...
#
#                             tweet_date sentiment query_used
# 325610  Fri Sep 07 06:53:11 +0000 2018  Negativo         :(
# 295144  Tue Sep 04 23:49:17 +0000 2018  Positivo         :)
# 86822   Mon Aug 20 20:56:00 +0000 2018  Negativo         :(
# 222433  Sat Aug 25 16:26:47 +0000 2018  Negativo         :(
# 768186  Mon Oct 08 07:39:23 +0000 2018  Positivo         :)

# %%
no_theme_tweets.sentiment.unique()
# Out:
# array(['Positivo', 'Negativo'], dtype=object)

# %%
series = no_theme_tweets['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = no_theme_tweets['sentiment'].value_counts()
por_neg = (series.Negativo / ( series.Negativo + series.Positivo )) * 100
por_pos = (series.Positivo / ( series.Negativo + series.Positivo )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 33.482096%
# Negativo = 66.517904%

# %% [markdown]
# ## File TweetsNeutralHash.csv

# %%
tweets_neutral_hash = pd.read_csv('dataset/TweetsNeutralHash.csv')

# %%
print(len(tweets_neutral_hash))
tweets_neutral_hash.sample(5)
# Out:
# 15727
#                         id                                         tweet_text  \
# 15441  1050208117567442944  "EXTRATO DA ATA DA REUNIÃO DO COLEGIADO Nº 39 ...
# 10115  1038776294622683137  Veja o que &amp;eacute; #FATO ou #FAKE na entr...
# 1771   1027594882968211459  #oportunidade de #negocio em #bh #confira http...
# 14722  1053240397177217024  Decisão e coragem traça destino. Quer saber ma...
# 5478   1032668990076805120  #Vaga para Auxiliar de Produção - Operacional ...
#
#                            tweet_date sentiment     query_used
# 15441  Thu Oct 11 02:15:01 +0000 2018    Neutro      #trabalho
# 10115  Sun Sep 09 13:09:02 +0000 2018    Neutro          #fato
# 1771   Thu Aug 09 16:38:06 +0000 2018    Neutro  #oportunidade
# 14722  Fri Oct 19 11:04:13 +0000 2018    Neutro  #oportunidade
# 5478   Thu Aug 23 16:40:47 +0000 2018    Neutro  #oportunidade

# %%
tweets_neutral_hash.sentiment.unique()
# Out:
# array(['Neutro'], dtype=object)

# %%
series = tweets_neutral_hash['query_used'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Hashtag')
ax.set_ylabel('Folder')
plt.show()

# %% [markdown]
# ## File TweetsNeutralNews.csv

# %%
tweets_neutral_news = pd.read_csv('dataset/TweetsNeutralNews.csv')

# %%
print(len(tweets_neutral_news))
tweets_neutral_news.sample(5)
# Out:
# 37556
#                         id                                         tweet_text  \
# 17581  1029422947122012161  FGTS vai distribuir R$ 6,23 bi entre trabalhad...
# 13834  1025002274454745088  Candidatura do Meirelles 'é ridícula' e será '...
# 12167  1028793254421049344  Dia dos Pais: Justiça dá direito a jovem de It...
# 16101  1036913483349151746  Amazon e Whole Foods, um ano depois https://t....
# 10975  1030428699856920576  Dólar sobe forte nesta sexta e chega a R$ 3,95...
#
#                            tweet_date sentiment    query_used
# 17581  Tue Aug 14 17:42:11 +0000 2018    Neutro         exame
# 13834  Thu Aug 02 12:56:00 +0000 2018    Neutro  jornaloglobo
# 12167  Mon Aug 13 00:00:00 +0000 2018    Neutro            g1
# 16101  Tue Sep 04 09:46:54 +0000 2018    Neutro         exame
# 10975  Fri Aug 17 12:18:41 +0000 2018    Neutro            g1

# %%
tweets_neutral_news.sentiment.unique()
# Out:
# array(['Neutro'], dtype=object)

# %%
series = tweets_neutral_news['query_used'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Hashtag')
ax.set_ylabel('Folder')
plt.show()

# %% [markdown]
# ## File TweetsNeutralHash.csv

# %%
tweets_neutral_theme = pd.read_csv('dataset/TweetsWithTheme.csv')

# %%
print(len(tweets_neutral_theme))
tweets_neutral_theme.sample(5)
# Out:
# 61591
#                         id                                         tweet_text  \
# 51283  1049078504191668224  Independente do presidente, já estou muito fel...
# 56880  1053072220740837381  @folha Porra, quem dera bancasse, tô cheio de ...
# 57827  1053028605775761409  @17_presidente @jairbolsonaro Eu, eu mesma e I...
# 15312  1040344470439567360  😍😍 Queres ver ainda mais novidades? 😍😍 Então p...
# 50477  1049720125140717569  @paulohporto minha mãe já tá falando pra eu nã...
#
#                            tweet_date sentiment         query_used
# 51283  Sun Oct 07 23:26:20 +0000 2018  Positivo        politica :)
# 56880  Thu Oct 18 23:55:57 +0000 2018  Positivo              PT :)
# 57827  Thu Oct 18 21:02:38 +0000 2018  Positivo  @jairbolsonaro :)
# 15312  Thu Sep 13 21:00:25 +0000 2018  Positivo              PT :)
# 50477  Tue Oct 09 17:55:55 +0000 2018  Negativo        politica :(

# %%
tweets_neutral_theme.sentiment.unique()
# Out:
# array(['Negativo', 'Positivo'], dtype=object)

# %%
series = tweets_neutral_theme['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = tweets_neutral_theme['sentiment'].value_counts()
por_neg = (series.Negativo / ( series.Negativo + series.Positivo )) * 100
por_pos = (series.Positivo / ( series.Negativo + series.Positivo )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 53.163612%
# Negativo = 46.836388%

# %% [markdown]
# # Folder de testdatasets

# %% [markdown]
# ## File Tests.csv

# %%
tests = pd.read_csv('dataset/TestDatasets/Test.csv',delimiter=';')

# %%
print(len(tests))
tests.sample(5)
# Out:
# 5000
#                        id                                         tweet_text  \
# 2528  1030495309615517697  hoje eu tive que ouvir de uma menina de 7 anos...
# 777   1029552986203320322  CADÊ OS COVER NESSE SITE — rs :) https://t.co/...
# 2960  1030500782225932293  Esse ano comprei dois fones, todos os dois pif...
# 3733  1030510367691157504                      minha mainha foi embora hj :(
# 2080  1029606327843049477      @SabeenaTamang @BSF_India vande matram mam :)
#
#                           tweet_date  sentiment query_used
# 2528  Fri Aug 17 16:43:22 +0000 2018          0         :(
# 777   Wed Aug 15 02:18:54 +0000 2018          1         :)
# 2960  Fri Aug 17 17:05:06 +0000 2018          0         :(
# 3733  Fri Aug 17 17:43:12 +0000 2018          0         :(
# 2080  Wed Aug 15 05:50:52 +0000 2018          1         :)

# %%
print(tests.sentiment.unique())
# Out:
# [1 0]

# %%
series = tests['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = tests['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1] )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# ## File Test3classes.csv

# %%
test3classes = pd.read_csv('dataset/TestDatasets/Test3classes.csv',delimiter=';')

# %%
print(len(test3classes))
test3classes.sample(5)
# Out:
# 4999
#                        id                                         tweet_text  \
# 1335  1029565388940435457  Gostei de um vídeo @YouTube https://t.co/KdDCc...
# 983   1029557537803304965  @brupsilva Ooow, Bru, não perde seu tempo pens...
# 4784  1025001485992636416  Produção industrial cresce 13,1% de maio para ...
# 931   1029556486354202624  @RodrigoBarone6 @BlogDoPim Não, tem provas de ...
# 4010  1023614128689008640                            https://t.co/KL4CJaUOk1
#
#                           tweet_date  sentiment query_used
# 1335  Wed Aug 15 03:08:11 +0000 2018          1         :)
# 983   Wed Aug 15 02:36:59 +0000 2018          1         :)
# 4784  Thu Aug 02 12:52:52 +0000 2018          2      exame
# 931   Wed Aug 15 02:32:49 +0000 2018          1         :)
# 4010  Sun Jul 29 17:00:00 +0000 2018          2       veja

# %%
print(test3classes.sentiment.unique())
# Out:
# [1 0 2]

# %%
series = test3classes['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = test3classes['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] + series[2] )) * 100
por_pos = (series[1] / ( series[0] + series[1] + series[2] )) * 100
por_neu = (series[2] / ( series[0] + series[1] + series[2])) * 100
print("Positivo = %f%% \nNegativo = %f%% \nNeutro = %f%% " % (por_pos,por_neg,por_neu))
# Out:
# Positivo = 33.346669%
# Negativo = 33.326665%
# Neutro = 33.326665%

# %% [markdown]
# ## File TestTema.csv

# %%
testtema = pd.read_csv('dataset/TestDatasets/TestTema.csv',delimiter=';')

# %%
print(len(testtema))
testtema.sample(5)
# Out:
# 5000
#                        id                                         tweet_text  \
# 4623  1030337537150263296  alguem me dá R$ 1800 pra eu comprar o zenfone ...
# 3309  1026487588545282048  @ManuelaDavila @diImabr Pôxa, perdi a pêrola q...
# 3625  1027402514000474113  Não deu para o aborto legal na Argentina :( ht...
# 1340  1025553400237367296  1000 pessoas hoje no evento eko7.oficial em Ch...
# 3455  1026858938711584770  Minha cabeça dói só de pensar que sou obrigada...
#
#                           tweet_date  sentiment         query_used
# 4623  Fri Aug 17 06:16:26 +0000 2018          0            lula :(
# 3309  Mon Aug 06 15:18:06 +0000 2018          0  @manueladavila :(
# 3625  Thu Aug 09 03:53:42 +0000 2018          0          senado :(
# 1340  Sat Aug 04 01:25:59 +0000 2018          1           #sucesso
# 3455  Tue Aug 07 15:53:43 +0000 2018          0           votar :(

# %%
print(testtema.sentiment.unique())
# Out:
# [1 0]

# %%
series = testtema['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = testtema['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# # Folder de trainingdatasets

# %% [markdown]
# ## File Train100.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/Train100.csv',delimiter=';')

# %%
print(len(train))
train.sample(5)
# Out:
# 100000
#                         id                                         tweet_text  \
# 39449  1032415233195749376    @mayhondaa Eu tenho o azzaro,é muito bom msm :)
# 96449  1037875087972749314                            Quero o meu namorado :(
# 38188  1032435441759338502     @vicaarol_ chama no wpp, n tenho seu número :)
# 83804  1038168125924155392      @BrunaCardoso92 @cbeyosuga alguma notícia? :(
# 13657  1037351630465916932  A panelinha de pressão! Fazia de verdade!mae c...
#
#                            tweet_date  sentiment query_used
# 39449  Wed Aug 22 23:52:27 +0000 2018          1         :)
# 96449  Fri Sep 07 01:27:58 +0000 2018          0         :(
# 38188  Thu Aug 23 01:12:45 +0000 2018          1         :)
# 83804  Fri Sep 07 20:52:24 +0000 2018          0         :(
# 13657  Wed Sep 05 14:47:56 +0000 2018          1         :)

# %%
print(train.sentiment.unique())
# Out:
# [1 0]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# ## File Train200.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/Train200.csv',delimiter=';')
print(len(train))
train.sample(5)
# Out:
# 200000
#                          id  \
# 60883   1032623775546789891
# 50156   1036651235984777217
# 43348   1037289815300087808
# 128358  1040542950265184256
# 13904   1040159633946681345
#
#                                                tweet_text  \
# 60883                            @horiniaz obrigadaa :) 💖
# 50156   @rodrigocoelhoc Ahahahahahahahah, o que dizer ...
# 43348       @pleysumido Bom dia e boa quarta Henrique :))
# 128358     O que foi meu amor? :( https://t.co/BIoLAkLZqx
# 13904   @leeteukutted @isehunspcy @XIUWMINFUCK Tb espe...
#
#                             tweet_date  sentiment query_used
# 60883   Thu Aug 23 13:41:07 +0000 2018          1         :)
# 50156   Mon Sep 03 16:24:49 +0000 2018          1         :)
# 43348   Wed Sep 05 10:42:18 +0000 2018          1         :)
# 128358  Fri Sep 14 10:09:06 +0000 2018          0         :(
# 13904   Thu Sep 13 08:45:56 +0000 2018          1         :)

# %%
print(train.sentiment.unique())
# Out:
# [1 0]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# ## File Train300.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/Train300.csv',delimiter=';')
print(len(train))
train.sample(5)
# Out:
# 300000
#                          id  \
# 262648  1041794691732307968
# 207931  1043312593505542144
# 208849  1043305057775693824
# 185625  1044061473478201344
# 70694   1041806544399224832
#
#                                                tweet_text  \
# 262648  @Luis_Dudura que Deus te abençoe, como bebe es...
# 207931  @Moonkistico0202 o ruim dessa cal é q n adiant...
# 208849  @ElenMaria0 Oq é sorte pra você é azar pra mim...
# 185625                                @godliamp eu sei :(
# 70694   A embuste sabe que precisa cobrar $20 pila de ...
#
#                             tweet_date  sentiment query_used
# 262648  Mon Sep 17 21:03:04 +0000 2018          0         :(
# 207931  Sat Sep 22 01:34:40 +0000 2018          0         :(
# 208849  Sat Sep 22 01:04:44 +0000 2018          0         :(
# 185625  Mon Sep 24 03:10:27 +0000 2018          0         :(
# 70694   Mon Sep 17 21:50:10 +0000 2018          1         :)

# %%
print(train.sentiment.unique())
# Out:
# [1 0]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# ## File Train400.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/Train400.csv',delimiter=';')
print(len(train))
train.sample(5)
# Out:
# 400000
#                          id  \
# 264301  1043258230938509318
# 43438   1043179496445276160
# 237245  1044048981800734720
# 314150  1041779490307887104
# 196017  1030534696365637636
#
#                                                tweet_text  \
# 264301              pietro cmg :( https://t.co/4Uk6BvD1L4
# 43438   queria ta na praia c a caipirinha que eu gosto :)
# 237245  hoje fazem exatos dois meses que eu não vejo o...
# 314150            sofrendo de saudade da minha família :(
# 196017  @ladygaga ::). Ksksksksksks https://t.co/Add8F...
#
#                             tweet_date  sentiment query_used
# 264301  Fri Sep 21 21:58:39 +0000 2018          0         :(
# 43438   Fri Sep 21 16:45:47 +0000 2018          1         :)
# 237245  Mon Sep 24 02:20:49 +0000 2018          0         :(
# 314150  Mon Sep 17 20:02:40 +0000 2018          0         :(
# 196017  Fri Aug 17 19:19:52 +0000 2018          1         :)

# %%
print(train.sentiment.unique())
# Out:
# [1 0]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# ## File Train500.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/Train500.csv',delimiter=';')
print(len(train))
train.sample(5)
# Out:
# 500000
#                          id  \
# 231577  1030499990542733313
# 359596  1043216247524151296
# 208902  1031251590437658624
# 171072  1035215254253432834
# 374383  1042622518119608322
#
#                                                tweet_text  \
# 231577  @ElaxRap @FredSaragoca Hahahahaha és novo por ...
# 359596  queria tanto conversar com você mas sou tímida...
# 208902  oi vm se pegar? :) — vamo nao https://t.co/WCc...
# 171072  To procurando amiguinhos para gravar gameplay ...
# 374383          @yassmesquita não fala assim :( eu vouuuu
#
#                             tweet_date  sentiment query_used
# 231577  Fri Aug 17 17:01:58 +0000 2018          1         :)
# 359596  Fri Sep 21 19:11:50 +0000 2018          0         :(
# 208902  Sun Aug 19 18:48:33 +0000 2018          1         :)
# 171072  Thu Aug 30 17:18:44 +0000 2018          1         :)
# 374383  Thu Sep 20 03:52:33 +0000 2018          0         :(

# %%
print(train.sentiment.unique())
# Out:
# [1 0]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# ## File Train50.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/Train50.csv',delimiter=';')
print(len(train))
train.sample(5)
# Out:
# 50000
#                         id                                         tweet_text  \
# 34776  1049144045736546305  o freddie é tão fofo aaaaaaa :( https://t.co/y...
# 29147  1049281869651615745                                gente, o suplicy :(
# 15513  1047468700981514240  @xLucasFelix Aah, quando a fatura fecha o app ...
# 32610  1049181483653578752                meu tudo :( https://t.co/T68XlpZHuf
# 42771  1046940503751761920  @meowymina foi mais ou menos tava passando mal...
#
#                            tweet_date  sentiment query_used
# 34776  Mon Oct 08 03:46:47 +0000 2018          0         :(
# 29147  Mon Oct 08 12:54:27 +0000 2018          0         :(
# 15513  Wed Oct 03 12:49:33 +0000 2018          1         :)
# 32610  Mon Oct 08 06:15:33 +0000 2018          0         :(
# 42771  Tue Oct 02 01:50:41 +0000 2018          0         :(

# %%
print(train.sentiment.unique())
# Out:
# [1 0]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%

# %% [markdown]
# ## File Train3Classes.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/Train3Classes.csv',delimiter=';')
print(len(train))
train.sample(5)
# Out:
# 100000
#                         id                                         tweet_text  \
# 61770  1046691906330251271  infelizmente tive uma crise de ansiedade no fi...
# 87941  1036763270055714816  ‘Não precisa coragem’, afirma Fátima Bernardes...
# 66309  1046227421358370818  @Breninbfr AI AMOR VC FOI P FESTA E NEM ME LEV...
# 13894  1047505428534493189                    @KaseBrasil Tô doido pra ver :)
# 43037  1049144702589648896  @goldenpills Amiga força!! Tá difícil agora ma...
#
#                            tweet_date  sentiment query_used
# 61770  Mon Oct 01 09:22:51 +0000 2018          0         :(
# 87941  Mon Sep 03 23:50:00 +0000 2018          2    estadao
# 66309  Sun Sep 30 02:37:09 +0000 2018          0         :(
# 13894  Wed Oct 03 15:15:30 +0000 2018          1         :)
# 43037  Mon Oct 08 03:49:23 +0000 2018          0         :(

# %%
print(train.sentiment.unique())
# Out:
# [1 0 2]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000750%
# Negativo = 49.999250%

# %% [markdown]
# ## File TrainTema.csv

# %%
train = pd.read_csv('dataset/TrainingDatasets/TrainTema.csv',delimiter=';')
print(len(train))
train.sample(5)
# Out:
# 50000
#                         id                                         tweet_text  \
# 15376  1047147208133554177            @ManuelaDavila Faltou o link, gente! :)
# 27697  1052310711865630720  O canal da Filarmonia pt desapareceu :( tinham...
# 40995  1047335368549441536  @Magnoski E se diretório quiser fazer algo a r...
# 49879  1036102472790630401  ja deu pt? — Eu nunca nem bebi pra isso :( htt...
# 31431  1049438437865152512  Como foi o melhor sonho que você já teve? — Ci...
#
#                            tweet_date  sentiment         query_used
# 15376  Tue Oct 02 15:32:04 +0000 2018          1  @manueladavila :)
# 27697  Tue Oct 16 21:29:59 +0000 2018          0              PT :(
# 40995  Wed Oct 03 03:59:45 +0000 2018          0     autoritario :(
# 49879  Sun Sep 02 04:04:14 +0000 2018          0              PT :(
# 31431  Mon Oct 08 23:16:35 +0000 2018          0            ciro :(

# %%
print(train.sentiment.unique())
# Out:
# [1 0]

# %%
series = train['sentiment'].value_counts()
ax = series.plot(kind='bar', title='')
ax.set_xlabel('Sentimento')
ax.set_ylabel('Folder')
plt.show()

# %%
series = train['sentiment'].value_counts()
por_neg = (series[0]/ ( series[0]+ series[1] )) * 100
por_pos = (series[1] / ( series[0] + series[1]  )) * 100
print("Positivo = %f%% \nNegativo = %f%% " % (por_pos,por_neg))
# Out:
# Positivo = 50.000000%
# Negativo = 50.000000%
